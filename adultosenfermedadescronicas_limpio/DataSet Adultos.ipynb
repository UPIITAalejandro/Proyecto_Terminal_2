# %%
# Importamos las librerias necesarias
import pandas as pd
pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
# Lectura de los DataFrames del 2010 al 2018
df = pd.read_csv("2010_adultos.csv")
df_1 = pd.read_csv("2011_adultos.csv")
df_2 = pd.read_csv("2012_adultos.csv")
df_3 = pd.read_csv("2013_adultos.csv")
df_4 = pd.read_csv("2014_adultos.csv")
df_5 = pd.read_csv("2015_adultos.csv")
df_6 = pd.read_csv("2016_adultos.csv")
df_7 = pd.read_csv("2017_adultos.csv")
df_8 = pd.read_csv("2018_adultos.csv")

# %% [markdown]
# ## Analisis exploratorio
#
# Dado la gran cantidad de DataFrame se hara solomante a un DataFrame, ya que los demas son analogos.

# %%
df.head()
# Out:
#                ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 0       AGUASCALIENTES  2010                              707
# 1      BAJA CALIFORNIA  2010                             1540
# 2  BAJA CALIFORNIA SUR  2010                              256
# 3             CAMPECHE  2010                              520
# 4              CHIAPAS  2010                             1965
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 0                             220                               413
# 1                             536                              1009
# 2                              65                               193
# 3                             148                               231
# 4                             703                               854
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# 0                              149                               23768
# ...

# %%
df.tail()
# Out:
#        ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 27  TAMAULIPAS  2010                             1856
# 28    TLAXCALA  2010                              646
# 29    VERACRUZ  2010                             3666
# 30     YUCATAN  2010                              661
# 31   ZACATECAS  2010                              595
#
#     DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 27                             738                               898
# 28                             233                               336
# 29                            1198                              1787
# 30                             198                               360
# 31                             267                               342
#
#     DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# 27                              391                               80380
# 28                              177                               54292
# ...

# %%
# Forma del DataSet
df.shape
# Out:
# (32, 26)

# %%
# Informacion de la columna estados
df.ENTIDAD.value_counts()
# Out:
# SONORA                 1
# DISTRITO FEDERAL       1
# GUANAJUATO             1
# TLAXCALA               1
# MEXICO                 1
# SINALOA                1
# DURANGO                1
# SAN LUIS POTOSI        1
# AGUASCALIENTES         1
# VERACRUZ               1
# PUEBLA                 1
# QUINTANA ROO           1
# COAHUILA               1
# OAXACA                 1
# CHIHUAHUA              1
# GUERRERO               1
# NUEVO LEON             1
# BAJA CALIFORNIA        1
# BAJA CALIFORNIA SUR    1
# CHIAPAS                1
# HIDALGO                1
# JALISCO                1
# NAYARIT                1
# ZACATECAS              1
# MICHOACAN              1
# TABASCO                1
# YUCATAN                1
# COLIMA                 1
# TAMAULIPAS             1
# QUERETARO              1
# MORELOS                1
# CAMPECHE               1
# Name: ENTIDAD, dtype: int64

# %%
# Verificacion de datos nulos
df.isnull().sum()
# Out:
# ENTIDAD                                0
# ANIO                                   0
# DIABETES_INGRESOS_MUJER_20_A_59        0
# DIABETES_INGRESOS_MUJER_60_MAS         0
# DIABETES_INGRESOS_HOMBRE_20_A_59       0
# DIABETES_INGRESOS_HOMBRE_60_MAS        0
# DIABETES_TRATAMIENTO_MUJER_20_A_59     0
# DIABETES_TRATAMIENTO_MUJER_60_MAS      0
# DIABETES_TRATAMIENTO_HOMBRE_20_A_59    0
# DIABETES_TRATAMIENTO_HOMBRE_60_MAS     0
# DIABETES_CONTROLADOS_MUJER_20_A_59     0
# DIABETES_CONTROLADOS_MUJER_60_MAS      0
# DIABETES_CONTROLADOS_HOMBRE_20_A_59    0
# DIABETES_CONTROLADOS_HOMBRE_60_MAS     0
# OBESIDAD_INGRESOS_MUJER_20_A_59        0
# OBESIDAD_INGRESOS_MUJER_60_MAS         0
# OBESIDAD_INGRESOS_HOMBRE_20_A_59       0
# OBESIDAD_INGRESOS_HOMBRE_60_MAS        0
# OBESIDAD_TRATAMIENTO_MUJER_20_A_59     0
# OBESIDAD_TRATAMIENTO_MUJER_60_MAS      0
# OBESIDAD_TRATAMIENTO_HOMBRE_20_A_59    0
# OBESIDAD_TRATAMIENTO_HOMBRE_60_MAS     0
# OBESIDAD_CONTROLADOS_MUJER_20_A_59     0
# ...

# %%
df.columns
# Out:
# Index(['ENTIDAD', 'ANIO', 'DIABETES_INGRESOS_MUJER_20_A_59',
#        'DIABETES_INGRESOS_MUJER_60_MAS', 'DIABETES_INGRESOS_HOMBRE_20_A_59',
#        'DIABETES_INGRESOS_HOMBRE_60_MAS', 'DIABETES_TRATAMIENTO_MUJER_20_A_59',
#        'DIABETES_TRATAMIENTO_MUJER_60_MAS',
#        'DIABETES_TRATAMIENTO_HOMBRE_20_A_59',
#        'DIABETES_TRATAMIENTO_HOMBRE_60_MAS',
#        'DIABETES_CONTROLADOS_MUJER_20_A_59',
#        'DIABETES_CONTROLADOS_MUJER_60_MAS',
#        'DIABETES_CONTROLADOS_HOMBRE_20_A_59',
#        'DIABETES_CONTROLADOS_HOMBRE_60_MAS', 'OBESIDAD_INGRESOS_MUJER_20_A_59',
#        'OBESIDAD_INGRESOS_MUJER_60_MAS', 'OBESIDAD_INGRESOS_HOMBRE_20_A_59',
#        'OBESIDAD_INGRESOS_HOMBRE_60_MAS', 'OBESIDAD_TRATAMIENTO_MUJER_20_A_59',
#        'OBESIDAD_TRATAMIENTO_MUJER_60_MAS',
#        'OBESIDAD_TRATAMIENTO_HOMBRE_20_A_59',
#        'OBESIDAD_TRATAMIENTO_HOMBRE_60_MAS',
#        'OBESIDAD_CONTROLADOS_MUJER_20_A_59',
#        'OBESIDAD_CONTROLADOS_MUJER_60_MAS',
# ...

# %% [markdown]
# ## Modificaciones al DataFrame
#
# Como operaciones a realizar al DataFrame, se piensan concatenar los datos relacionados a los años 2010 al 2018 en un solo DataFrame

# %%
df_general = pd.concat([df,df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8],axis=0)

# %%
df_general.head()
# Out:
#                ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 0       AGUASCALIENTES  2010                              707
# 1      BAJA CALIFORNIA  2010                             1540
# 2  BAJA CALIFORNIA SUR  2010                              256
# 3             CAMPECHE  2010                              520
# 4              CHIAPAS  2010                             1965
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 0                             220                               413
# 1                             536                              1009
# 2                              65                               193
# 3                             148                               231
# 4                             703                               854
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# 0                              149                               23768
# ...

# %%
df_index = pd.DataFrame()
df_index['ID_ENTIDAD'] = df_general.index
df_index.index = df_index['ID_ENTIDAD']

df_general_1 = pd.concat([df_index,df_general],axis=1)

# %%
df_general_1.head()
# Out:
#    ID_ENTIDAD              ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 0           0       AGUASCALIENTES  2010                              707
# 1           1      BAJA CALIFORNIA  2010                             1540
# 2           2  BAJA CALIFORNIA SUR  2010                              256
# 3           3             CAMPECHE  2010                              520
# 4           4              CHIAPAS  2010                             1965
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 0                             220                               413
# 1                             536                              1009
# 2                              65                               193
# 3                             148                               231
# 4                             703                               854
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# ...

# %%
df_general_1['ENTIDAD'] = df_general_1['ENTIDAD'].str.lower()
df_general_1['ENTIDAD'] = df_general_1['ENTIDAD'].str.title()
df_general_1.head()
# Out:
#    ID_ENTIDAD              ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 0           0       Aguascalientes  2010                              707
# 1           1      Baja California  2010                             1540
# 2           2  Baja California Sur  2010                              256
# 3           3             Campeche  2010                              520
# 4           4              Chiapas  2010                             1965
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 0                             220                               413
# 1                             536                              1009
# 2                              65                               193
# 3                             148                               231
# 4                             703                               854
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# ...

# %%
df_general_1['ENTIDAD'].value_counts()
# Out:
# Michoacan              9
# Yucatan                9
# Tlaxcala               9
# Puebla                 9
# Coahuila               9
# Oaxaca                 9
# Quintana Roo           9
# Nuevo Leon             9
# Morelos                9
# Sonora                 9
# Nayarit                9
# Hidalgo                9
# Mexico                 9
# Campeche               9
# Guerrero               9
# Sinaloa                9
# San Luis Potosi        9
# Aguascalientes         9
# Baja California        9
# Colima                 9
# Veracruz               9
# Tamaulipas             9
# Guanajuato             9
# Chihuahua              9
# Queretaro              9
# Jalisco                9
# Chiapas                9
# Durango                9
# Baja California Sur    9
# Tabasco                9
# Zacatecas              9
# Distrito Federal       8
# Ciudad De Mexico       1
# Name: ENTIDAD, dtype: int64

# %%
df_general_1[df_general_1['ENTIDAD']=='Ciudad De Mexico']
# Out:
#    ID_ENTIDAD           ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 6           6  Ciudad De Mexico  2018                             3101
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 6                            1990                              2175
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# 6                             1240                              132929
#
#    DIABETES_TRATAMIENTO_MUJER_60_MAS  DIABETES_TRATAMIENTO_HOMBRE_20_A_59  \
# 6                             121414                                61680
#
#    DIABETES_TRATAMIENTO_HOMBRE_60_MAS  DIABETES_CONTROLADOS_MUJER_20_A_59  \
# 6                               53983                               46081
#
#    DIABETES_CONTROLADOS_MUJER_60_MAS  DIABETES_CONTROLADOS_HOMBRE_20_A_59  \
# 6                              50023                                20532
#
#    DIABETES_CONTROLADOS_HOMBRE_60_MAS  OBESIDAD_INGRESOS_MUJER_20_A_59  \
# ...

# %%
df_general_1['ENTIDAD']=df_general_1['ENTIDAD'].str.replace('Distrito Federal','Ciudad De Mexico')
df_general_1['ENTIDAD'].value_counts()
# Out:
# Michoacan              9
# Aguascalientes         9
# Tlaxcala               9
# Puebla                 9
# Ciudad De Mexico       9
# Oaxaca                 9
# Nuevo Leon             9
# Sinaloa                9
# Sonora                 9
# Nayarit                9
# Hidalgo                9
# Mexico                 9
# Campeche               9
# Guerrero               9
# Morelos                9
# Yucatan                9
# Coahuila               9
# Quintana Roo           9
# Colima                 9
# Veracruz               9
# Tamaulipas             9
# Guanajuato             9
# Chihuahua              9
# Queretaro              9
# Jalisco                9
# Chiapas                9
# Baja California        9
# Baja California Sur    9
# Durango                9
# Tabasco                9
# Zacatecas              9
# San Luis Potosi        9
# Name: ENTIDAD, dtype: int64

# %%
df_general_1.head()
# Out:
#    ID_ENTIDAD              ENTIDAD  ANIO  DIABETES_INGRESOS_MUJER_20_A_59  \
# 0           0       Aguascalientes  2010                              707
# 1           1      Baja California  2010                             1540
# 2           2  Baja California Sur  2010                              256
# 3           3             Campeche  2010                              520
# 4           4              Chiapas  2010                             1965
#
#    DIABETES_INGRESOS_MUJER_60_MAS  DIABETES_INGRESOS_HOMBRE_20_A_59  \
# 0                             220                               413
# 1                             536                              1009
# 2                              65                               193
# 3                             148                               231
# 4                             703                               854
#
#    DIABETES_INGRESOS_HOMBRE_60_MAS  DIABETES_TRATAMIENTO_MUJER_20_A_59  \
# ...

# %% [markdown]
# ## Definicion de diccionario

# %%
df_general_1.columns
# Out:
# Index(['ID_ENTIDAD', 'ENTIDAD', 'ANIO', 'DIABETES_INGRESOS_MUJER_20_A_59',
#        'DIABETES_INGRESOS_MUJER_60_MAS', 'DIABETES_INGRESOS_HOMBRE_20_A_59',
#        'DIABETES_INGRESOS_HOMBRE_60_MAS', 'DIABETES_TRATAMIENTO_MUJER_20_A_59',
#        'DIABETES_TRATAMIENTO_MUJER_60_MAS',
#        'DIABETES_TRATAMIENTO_HOMBRE_20_A_59',
#        'DIABETES_TRATAMIENTO_HOMBRE_60_MAS',
#        'DIABETES_CONTROLADOS_MUJER_20_A_59',
#        'DIABETES_CONTROLADOS_MUJER_60_MAS',
#        'DIABETES_CONTROLADOS_HOMBRE_20_A_59',
#        'DIABETES_CONTROLADOS_HOMBRE_60_MAS', 'OBESIDAD_INGRESOS_MUJER_20_A_59',
#        'OBESIDAD_INGRESOS_MUJER_60_MAS', 'OBESIDAD_INGRESOS_HOMBRE_20_A_59',
#        'OBESIDAD_INGRESOS_HOMBRE_60_MAS', 'OBESIDAD_TRATAMIENTO_MUJER_20_A_59',
#        'OBESIDAD_TRATAMIENTO_MUJER_60_MAS',
#        'OBESIDAD_TRATAMIENTO_HOMBRE_20_A_59',
#        'OBESIDAD_TRATAMIENTO_HOMBRE_60_MAS',
#        'OBESIDAD_CONTROLADOS_MUJER_20_A_59',
#        'OBESIDAD_CONTROLADOS_MUJER_60_MAS',
# ...

# %% [markdown]
# ## Metodologia Diccionario
# Para definir el diccionario se usara la siguiente metodologia:
#
#
# Las tres primeras letras de la enfermidad, más las dos primeras del genero, las tres primeras letras si esta en tratamiento, ingreso o controlado y por ultimo las edades.
#
# Siendo de la siguiente manera.
#
#
# `DIABETES_INGRESOS_MUJER_20_A_59` se representaria de la siguiente manera `DIA_ING_MU_20_59`.

# %%
diccionario= {
    'ID_ENTIDAD':'Id', 
    'ENTIDAD':'Estado', 
    'ANIO':'Anio', 
    'DIABETES_INGRESOS_MUJER_20_A_59':'DIA_ING_MU_20_59',
    'DIABETES_INGRESOS_MUJER_60_MAS':'DIA_ING_MU_60_MAS', 
    'DIABETES_INGRESOS_HOMBRE_20_A_59':'DIA_ING_HO_20_59',
    'DIABETES_INGRESOS_HOMBRE_60_MAS':'DIA_ING_HO_60_MAS', 
    'DIABETES_TRATAMIENTO_MUJER_20_A_59':'DIA_TRA_MU_20_59',
    'DIABETES_TRATAMIENTO_MUJER_60_MAS':'DIA_TRA_MU_60_MAS',
    'DIABETES_TRATAMIENTO_HOMBRE_20_A_59':'DIA_TRA_HO_20_59',
    'DIABETES_TRATAMIENTO_HOMBRE_60_MAS':'DIA_TRA_HO_60_MAS',
    'DIABETES_CONTROLADOS_MUJER_20_A_59':'DIA_CON_MU_20_59',
    'DIABETES_CONTROLADOS_MUJER_60_MAS':'DIA_CON_MU_60_MAS',
    'DIABETES_CONTROLADOS_HOMBRE_20_A_59':'DIA_CON_HO_20_59',
    'DIABETES_CONTROLADOS_HOMBRE_60_MAS':'DIA_CON_MU_60_MAS', 
    'OBESIDAD_INGRESOS_MUJER_20_A_59':'OBE_ING_MU_20_59',
    'OBESIDAD_INGRESOS_MUJER_60_MAS':'OBE_ING_MU_60_MAS', 
    'OBESIDAD_INGRESOS_HOMBRE_20_A_59':'OBE_ING_HO_20_59',
    'OBESIDAD_INGRESOS_HOMBRE_60_MAS':'OBE_ING_HO_60_MAS', 
    'OBESIDAD_TRATAMIENTO_MUJER_20_A_59':'OBE_TRA_MU_20_59',
    'OBESIDAD_TRATAMIENTO_MUJER_60_MAS':'OBE_TRA_MU_60_MAS',
    'OBESIDAD_TRATAMIENTO_HOMBRE_20_A_59':'OBE_TRA_HO_20_59',
    'OBESIDAD_TRATAMIENTO_HOMBRE_60_MAS':'OBE_TRA_HO_60_MAS',
    'OBESIDAD_CONTROLADOS_MUJER_20_A_59':'OBE_CON_MU_20_59',
    'OBESIDAD_CONTROLADOS_MUJER_60_MAS':'OBE_CON_MU_60_MAS',
    'OBESIDAD_CONTROLADOS_HOMBRE_20_A_59':'OBE_CON_HO_20_59',
    'OBESIDAD_CONTROLADOS_HOMBRE_60_MAS':'OBE_CON_MU_60_MAS'
}

df_general_2 = df_general_1.rename(columns=diccionario).copy()

#df_genral_1
#df_general_1.sort_values(by=['Anio','Estado'])

# %%
df_general_2
# Out:
#     Id               Estado  Anio  DIA_ING_MU_20_59  DIA_ING_MU_60_MAS  \
# 0    0       Aguascalientes  2010               707                220
# 1    1      Baja California  2010              1540                536
# 2    2  Baja California Sur  2010               256                 65
# 3    3             Campeche  2010               520                148
# 4    4              Chiapas  2010              1965                703
# 5    5            Chihuahua  2010              2073                767
# 6    6             Coahuila  2010               332                 84
# 7    7               Colima  2010               290                112
# 8    8     Ciudad De Mexico  2010              2855               1299
# 9    9              Durango  2010               485                163
# 10  10           Guanajuato  2010              3061               1197
# 11  11             Guerrero  2010              2334                778
# ...

# %%
df_general_ordenado = df_general_2.sort_values(by = ['Anio','Estado'])

# %%
estados =list(df_general_ordenado.Estado.value_counts().index)

# %%
estados.sort()
estados
# Out:
# ['Aguascalientes',
#  'Baja California',
#  'Baja California Sur',
#  'Campeche',
#  'Chiapas',
#  'Chihuahua',
#  'Ciudad De Mexico',
#  'Coahuila',
#  'Colima',
#  'Durango',
#  'Guanajuato',
#  'Guerrero',
#  'Hidalgo',
#  'Jalisco',
#  'Mexico',
#  'Michoacan',
#  'Morelos',
#  'Nayarit',
#  'Nuevo Leon',
#  'Oaxaca',
#  'Puebla',
#  'Queretaro',
#  'Quintana Roo',
#  'San Luis Potosi',
#  'Sinaloa',
#  'Sonora',
#  'Tabasco',
#  'Tamaulipas',
#  'Tlaxcala',
#  'Veracruz',
#  'Yucatan',
#  'Zacatecas']

# %%
diccionario_id = {
 'Aguascalientes':1,
 'Baja California':2,
 'Baja California Sur':3,
 'Campeche':4,
 'Chiapas':5,
 'Chihuahua':6,
 'Ciudad De Mexico':7,
 'Coahuila':8,
 'Colima':9,
 'Durango':10,
 'Guanajuato':11,
 'Guerrero':12,
 'Hidalgo':13,
 'Jalisco':14,
 'Mexico':15,
 'Michoacan':16,
 'Morelos':17,
 'Nayarit':18,
 'Nuevo Leon':19,
 'Oaxaca':20,
 'Puebla':21,
 'Queretaro':22,
 'Quintana Roo':23,
 'San Luis Potosi':24,
 'Sinaloa':25,
 'Sonora':26,
 'Tabasco':27,
 'Tamaulipas':28,
 'Tlaxcala':29,
 'Veracruz':30,
 'Yucatan':31,
 'Zacatecas':32
}

df_aux = pd.DataFrame()

df_aux['Id'] = df_general_ordenado['Estado']
df_aux['Id'] = df_aux.replace(diccionario_id)

# %%
df_general_ordenado_1 = df_general_ordenado.drop(columns=['Id']).copy()
df_general_ordenado_1.head()
# Out:
#                 Estado  Anio  DIA_ING_MU_20_59  DIA_ING_MU_60_MAS  \
# 0       Aguascalientes  2010               707                220
# 1      Baja California  2010              1540                536
# 2  Baja California Sur  2010               256                 65
# 3             Campeche  2010               520                148
# 4              Chiapas  2010              1965                703
#
#    DIA_ING_HO_20_59  DIA_ING_HO_60_MAS  DIA_TRA_MU_20_59  DIA_TRA_MU_60_MAS  \
# 0               413                149             23768              11096
# 1              1009                386             35470              18096
# 2               193                 44             12239               4671
# 3               231                 86             35996              14807
# 4               854                349             90868              39274
#
#    DIA_TRA_HO_20_59  DIA_TRA_HO_60_MAS  DIA_CON_MU_20_59  DIA_CON_MU_60_MAS  \
# ...

# %%
df_final = pd.concat([df_aux,df_general_ordenado_1],axis=1)

# %%
df_final.to_csv('DataSet_Datos_Diabetes_SALUD.csv',index=False)

# %%
df_final
# Out:
#     Id               Estado  Anio  DIA_ING_MU_20_59  DIA_ING_MU_60_MAS  \
# 0    1       Aguascalientes  2010               707                220
# 1    2      Baja California  2010              1540                536
# 2    3  Baja California Sur  2010               256                 65
# 3    4             Campeche  2010               520                148
# 4    5              Chiapas  2010              1965                703
# 5    6            Chihuahua  2010              2073                767
# 8    7     Ciudad De Mexico  2010              2855               1299
# 6    8             Coahuila  2010               332                 84
# 7    9               Colima  2010               290                112
# 9   10              Durango  2010               485                163
# 10  11           Guanajuato  2010              3061               1197
# 11  12             Guerrero  2010              2334                778
# ...
