# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df_2008 = pd.read_csv("2008.csv")
df_2010 = pd.read_csv("2010.csv")
df_2012 = pd.read_csv("2012.csv")
df_2014 = pd.read_csv("2014.csv")
df_2016 = pd.read_csv("2016.csv")
df_2018 = pd.read_csv("2018.csv")

# %%
df_2008.head()
# Out:
#               estado_1  anio  porc_la_pob_ocupada_sin_acces_seguridad_social  \
# 0       aguascalientes  2008                                            51.7
# 1      baja_california  2008                                            52.0
# 2  baja_california_sur  2008                                            51.1
# 3             campeche  2008                                            59.2
# 4             coahuila  2008                                            37.4
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial  \
# 0                                          222.61
# 1                                          659.37
# 2                                          133.35
# 3                                          200.43
# 4                                          380.45
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social  \
# 0                                               45.0
# 1                                               45.9
# 2                                               41.0
# 3                                               51.7
# 4                                               29.7
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social  \
# 0                                             134.52
# 1                                             361.92
# 2                                              58.62
# 3                                             106.40
# 4                                             224.66
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social  \
# 0                                               24.7
# 1                                               32.7
# 2                                               16.5
# 3                                               32.1
# 4                                               15.9
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social
# 0                                              14.63
# 1                                              52.10
# 2                                               4.49
# 3                                              16.04
# 4                                              28.04

# %%
df_2008.shape
# Out:
# (32, 8)

# %%
# Verificacion que todos los dataFrame tenga la misma cabecera
list(df_2008.columns) == list(df_2010.columns) == list(df_2012.columns) == list(df_2014.columns) == list(df_2016.columns) == list(df_2018.columns)
# Out:
# True

# %%
# Verificacion que toda la columna "estado_1" tenga el mismo orden en los estados 
list(df_2008['estado_1']) == list(df_2010['estado_1']) == list(df_2012['estado_1']) == list(df_2014['estado_1']) == list(df_2016['estado_1']) == list(df_2018['estado_1'])
# Out:
# True

# %%
df_2008.columns
# Out:
# Index(['estado_1', 'anio', 'porc_la_pob_ocupada_sin_acces_seguridad_social',
#        'miles_perso_ocupadas_sin_acces_seguridadsocial',
#        'porc_la_pob_no_economi_activa_sin_acces_seguridad_social',
#        'miles_perso_no_economi_activa_sin_acces_seguridad_social',
#        'porc_la_pob_65_anios_mas_sin_acces_seguridad_social',
#        'miles_perso_65_anios_mas_sin_acces_seguridad_social'],
#       dtype='object')

# %%
# Creacion del diccionario para datos faltantes
diccionario_anios_faltantes = {
    'estado_1':list(df_2008['estado_1']), 
    'anio':list(np.nan for i in range(0,32)), 
    'porc_la_pob_ocupada_sin_acces_seguridad_social':list(np.nan for i in range(0,32)),
    'miles_perso_ocupadas_sin_acces_seguridadsocial':list(np.nan for i in range(0,32)),
    'porc_la_pob_no_economi_activa_sin_acces_seguridad_social':list(np.nan for i in range(0,32)),
    'miles_perso_no_economi_activa_sin_acces_seguridad_social':list(np.nan for i in range(0,32)),
    'porc_la_pob_65_anios_mas_sin_acces_seguridad_social':list(np.nan for i in range(0,32)),
    'miles_perso_65_anios_mas_sin_acces_seguridad_social':list(np.nan for i in range(0,32))
}

# %%
# Creacion de diccionario con datos faltantes

df_2009 = pd.DataFrame(diccionario_anios_faltantes)
df_2009['anio'] = 2009

df_2011 = pd.DataFrame(diccionario_anios_faltantes)
df_2011['anio'] = 2011

df_2013 = pd.DataFrame(diccionario_anios_faltantes)
df_2013['anio'] = 2013

df_2015 = pd.DataFrame(diccionario_anios_faltantes)
df_2015['anio'] = 2015

df_2017 = pd.DataFrame(diccionario_anios_faltantes)
df_2017['anio'] = 2017

# %%
df_general = pd.DataFrame()

for i in range(2,len(list(df_2008.columns))):
    
    #Recorrer para interpolacion 
    aux_2008 = df_2008.iloc[:,lambda df_2008:[i]]
    aux_2009 = df_2009.iloc[:,lambda df_2008:[i]]
    aux_2010 = df_2010.iloc[:,lambda df_2008:[i]]
    aux_2011 = df_2011.iloc[:,lambda df_2008:[i]]
    aux_2012 = df_2012.iloc[:,lambda df_2008:[i]]
    aux_2013 = df_2013.iloc[:,lambda df_2008:[i]]
    aux_2014 = df_2014.iloc[:,lambda df_2008:[i]]
    aux_2015 = df_2015.iloc[:,lambda df_2008:[i]]
    aux_2016 = df_2016.iloc[:,lambda df_2008:[i]]
    aux_2017 = df_2017.iloc[:,lambda df_2008:[i]]
    aux_2018 = df_2018.iloc[:,lambda df_2008:[i]]

    df_general_aux = pd.concat([aux_2008,aux_2009,aux_2010,aux_2011,aux_2012,aux_2013,aux_2014,aux_2015,aux_2016,aux_2017,aux_2018],axis=1)
    df_general_aux = df_general_aux.interpolate(method='linear',axis = 1).copy()
    
    lista_nombre_columnas = [list(aux_2008.columns)[0]+"_"+str(df_2008['anio'][0]),
        list(aux_2009.columns)[0]+"_"+str(df_2009['anio'][0]),list(aux_2010.columns)[0]+"_"+str(df_2010['anio'][0]),
        list(aux_2011.columns)[0]+"_"+str(df_2011['anio'][0]),list(aux_2012.columns)[0]+"_"+str(df_2012['anio'][0]),
        list(aux_2013.columns)[0]+"_"+str(df_2013['anio'][0]),list(aux_2014.columns)[0]+"_"+str(df_2014['anio'][0]),
        list(aux_2015.columns)[0]+"_"+str(df_2015['anio'][0]),list(aux_2016.columns)[0]+"_"+str(df_2016['anio'][0]),
        list(aux_2017.columns)[0]+"_"+str(df_2017['anio'][0]),list(aux_2018.columns)[0]+"_"+str(df_2018['anio'][0])]
    
    df_general_aux.columns = lista_nombre_columnas 
    
    df_general=pd.concat([df_general,df_general_aux],axis=1)

# %%
df_general.head()
# Out:
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2008  \
# 0                                               51.7
# 1                                               52.0
# 2                                               51.1
# 3                                               59.2
# 4                                               37.4
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2009  \
# 0                                              50.50
# 1                                              54.65
# 2                                              50.35
# 3                                              60.10
# 4                                              38.05
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2010  \
# 0                                               49.3
# 1                                               57.3
# 2                                               49.6
# 3                                               61.0
# 4                                               38.7
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2011  \
# 0                                              48.50
# 1                                              58.45
# 2                                              48.35
# 3                                              61.90
# 4                                              38.00
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2012  \
# 0                                               47.7
# 1                                               59.6
# 2                                               47.1
# 3                                               62.8
# 4                                               37.3
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2013  \
# 0                                              46.30
# 1                                              58.30
# 2                                              49.95
# 3                                              62.75
# 4                                              36.55
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2014  \
# 0                                               44.9
# 1                                               57.0
# 2                                               52.8
# 3                                               62.7
# 4                                               35.8
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2015  \
# 0                                              43.20
# 1                                              50.80
# 2                                              47.40
# 3                                              61.55
# 4                                              34.40
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2016  \
# 0                                               41.5
# 1                                               44.6
# 2                                               42.0
# 3                                               60.4
# 4                                               33.0
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2017  \
# 0                                              43.55
# 1                                              47.60
# 2                                              44.35
# 3                                              62.55
# 4                                              33.10
#
#    porc_la_pob_ocupada_sin_acces_seguridad_social_2018  \
# 0                                               45.6
# 1                                               50.6
# 2                                               46.7
# 3                                               64.7
# 4                                               33.2
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2008  \
# 0                                             222.61
# 1                                             659.37
# 2                                             133.35
# 3                                             200.43
# 4                                             380.45
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2009  \
# 0                                            222.685
# 1                                            687.640
# 2                                            131.090
# 3                                            212.430
# 4                                            409.245
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2010  \
# 0                                             222.76
# 1                                             715.91
# 2                                             128.83
# 3                                             224.43
# 4                                             438.04
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2011  \
# 0                                            233.475
# 1                                            745.805
# 2                                            136.175
# 3                                            231.250
# 4                                            452.215
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2012  \
# 0                                             244.19
# 1                                             775.70
# 2                                             143.52
# 3                                             238.07
# 4                                             466.39
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2013  \
# 0                                            243.385
# 1                                            795.755
# 2                                            158.595
# 3                                            257.535
# 4                                            453.280
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2014  \
# 0                                             242.58
# 1                                             815.81
# 2                                             173.67
# 3                                             277.00
# 4                                             440.17
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2015  \
# 0                                            247.175
# 1                                            774.040
# 2                                            164.670
# 3                                            273.585
# 4                                            430.685
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2016  \
# 0                                             251.77
# 1                                             732.27
# 2                                             155.67
# 3                                             270.17
# 4                                             421.20
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2017  \
# 0                                            268.390
# 1                                            789.485
# 2                                            172.805
# 3                                            286.680
# 4                                            432.140
#
#    miles_perso_ocupadas_sin_acces_seguridadsocial_2018  \
# 0                                             285.01
# 1                                             846.70
# 2                                             189.94
# 3                                             303.19
# 4                                             443.08
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2008  \
# 0                                               45.0
# 1                                               45.9
# 2                                               41.0
# 3                                               51.7
# 4                                               29.7
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2009  \
# 0                                              44.55
# 1                                              47.30
# 2                                              40.00
# 3                                              51.20
# 4                                              29.20
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2010  \
# 0                                               44.1
# 1                                               48.7
# 2                                               39.0
# 3                                               50.7
# 4                                               28.7
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2011  \
# 0                                              42.40
# 1                                              46.90
# 2                                              38.15
# 3                                              51.05
# 4                                              27.05
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2012  \
# 0                                               40.7
# 1                                               45.1
# 2                                               37.3
# 3                                               51.4
# 4                                               25.4
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2013  \
# 0                                              38.50
# 1                                              44.90
# 2                                              37.45
# 3                                              49.80
# 4                                              26.90
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2014  \
# 0                                               36.3
# 1                                               44.7
# 2                                               37.6
# 3                                               48.2
# 4                                               28.4
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2015  \
# 0                                              35.30
# 1                                              42.25
# 2                                              36.40
# 3                                              47.85
# 4                                              26.40
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2016  \
# 0                                               34.3
# 1                                               39.8
# 2                                               35.2
# 3                                               47.5
# 4                                               24.4
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2017  \
# 0                                              35.45
# 1                                              39.10
# 2                                              34.85
# 3                                              46.90
# 4                                              24.75
#
#    porc_la_pob_no_economi_activa_sin_acces_seguridad_social_2018  \
# 0                                               36.6
# 1                                               38.4
# 2                                               34.5
# 3                                               46.3
# 4                                               25.1
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2008  \
# 0                                             134.52
# 1                                             361.92
# 2                                              58.62
# 3                                             106.40
# 4                                             224.66
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2009  \
# 0                                            134.980
# 1                                            408.145
# 2                                             64.305
# 3                                            104.015
# 4                                            212.830
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2010  \
# 0                                             135.44
# 1                                             454.37
# 2                                              69.99
# 3                                             101.63
# 4                                             201.00
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2011  \
# 0                                            129.055
# 1                                            442.475
# 2                                             69.925
# 3                                            107.960
# 4                                            192.385
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2012  \
# 0                                             122.67
# 1                                             430.58
# 2                                              69.86
# 3                                             114.29
# 4                                             183.77
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2013  \
# 0                                            117.105
# 1                                            421.380
# 2                                             69.225
# 3                                             98.805
# 4                                            198.980
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2014  \
# 0                                             111.54
# 1                                             412.18
# 2                                              68.59
# 3                                              83.32
# 4                                             214.19
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2015  \
# 0                                            102.595
# 1                                            376.060
# 2                                             67.150
# 3                                             88.095
# 4                                            200.555
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2016  \
# 0                                              93.65
# 1                                             339.94
# 2                                              65.71
# 3                                              92.87
# 4                                             186.92
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2017  \
# 0                                            103.585
# 1                                            349.940
# 2                                             66.600
# 3                                             92.285
# 4                                            193.345
#
#    miles_perso_no_economi_activa_sin_acces_seguridad_social_2018  \
# 0                                             113.52
# 1                                             359.94
# 2                                              67.49
# 3                                              91.70
# 4                                             199.77
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2008  \
# 0                                               24.7
# 1                                               32.7
# 2                                               16.5
# 3                                               32.1
# 4                                               15.9
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2009  \
# 0                                              26.50
# 1                                              31.40
# 2                                              16.90
# 3                                              28.60
# 4                                              15.55
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2010  \
# 0                                               28.3
# 1                                               30.1
# 2                                               17.3
# 3                                               25.1
# 4                                               15.2
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2011  \
# 0                                              25.05
# 1                                              27.00
# 2                                              19.10
# 3                                              24.75
# 4                                              13.55
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2012  \
# 0                                               21.8
# 1                                               23.9
# 2                                               20.9
# 3                                               24.4
# 4                                               11.9
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2013  \
# 0                                              16.00
# 1                                              25.75
# 2                                              15.85
# 3                                              20.15
# 4                                              10.25
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2014  \
# 0                                               10.2
# 1                                               27.6
# 2                                               10.8
# 3                                               15.9
# 4                                                8.6
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2015  \
# 0                                               8.70
# 1                                              20.80
# 2                                               8.90
# 3                                              16.10
# 4                                               6.85
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2016  \
# 0                                                7.2
# 1                                               14.0
# 2                                                7.0
# 3                                               16.3
# 4                                                5.1
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2017  \
# 0                                               9.75
# 1                                              15.65
# 2                                               8.90
# 3                                              15.55
# 4                                               6.20
#
#    porc_la_pob_65_anios_mas_sin_acces_seguridad_social_2018  \
# 0                                               12.3
# 1                                               17.3
# 2                                               10.8
# 3                                               14.8
# 4                                                7.3
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2008  \
# 0                                              14.63
# 1                                              52.10
# 2                                               4.49
# 3                                              16.04
# 4                                              28.04
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2009  \
# 0                                             17.760
# 1                                             50.580
# 2                                              5.415
# 3                                             15.070
# 4                                             25.595
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2010  \
# 0                                              20.89
# 1                                              49.06
# 2                                               6.34
# 3                                              14.10
# 4                                              23.15
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2011  \
# 0                                             19.085
# 1                                             49.525
# 2                                              7.835
# 3                                             14.290
# 4                                             22.910
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2012  \
# 0                                              17.28
# 1                                              49.99
# 2                                               9.33
# 3                                              14.48
# 4                                              22.67
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2013  \
# 0                                             12.725
# 1                                             51.200
# 2                                              6.450
# 3                                             11.765
# 4                                             20.110
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2014  \
# 0                                               8.17
# 1                                              52.41
# 2                                               3.57
# 3                                               9.05
# 4                                              17.55
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2015  \
# 0                                              7.010
# 1                                             38.800
# 2                                              3.290
# 3                                              9.555
# 4                                             14.315
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2016  \
# 0                                               5.85
# 1                                              25.19
# 2                                               3.01
# 3                                              10.06
# 4                                              11.08
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2017  \
# 0                                              9.075
# 1                                             33.365
# 2                                              4.315
# 3                                              9.805
# 4                                             14.480
#
#    miles_perso_65_anios_mas_sin_acces_seguridad_social_2018
# 0                                              12.30
# 1                                              41.54
# 2                                               5.62
# 3                                               9.55
# 4                                              17.88

# %%
df_nombre = pd.concat([df_2008.iloc[:,[0]],df_2008.iloc[:,[0]]],axis = 1)
df_nombre.columns = ['Id','Estado']
df_nombre['Estado'] = df_nombre['Estado'].str.replace('_',' ')
df_nombre['Estado'] = df_nombre['Estado'].str.title()

df_nombre['Id'] = df_nombre['Estado']

diccionario_id = {
 'Aguascalientes':1,
 'Baja California':2,
 'Baja California Sur':3,
 'Campeche':4,
 'Chiapas':5,
 'Chihuahua':6,
 'Ciudad De Mexico':7,
 'Coahuila':8,
 'Colima':9,
 'Durango':10,
 'Guanajuato':11,
 'Guerrero':12,
 'Hidalgo':13,
 'Jalisco':14,
 'Mexico':15,
 'Michoacan':16,
 'Morelos':17,
 'Nayarit':18,
 'Nuevo Leon':19,
 'Oaxaca':20,
 'Puebla':21,
 'Queretaro':22,
 'Quintana Roo':23,
 'San Luis Potosi':24,
 'Sinaloa':25,
 'Sonora':26,
 'Tabasco':27,
 'Tamaulipas':28,
 'Tlaxcala':29,
 'Veracruz':30,
 'Yucatan':31,
 'Zacatecas':32
}



df_nombre['Id'] = df_nombre['Id'].replace(diccionario_id)

# %%
df_unido = pd.concat([df_nombre,df_general],axis=1)

# %%
df_final = df_unido.sort_values(by=['Id'])

# %%
df_final.to_csv("DataSet_Datos_Indice_C19C.csv", index = False)
