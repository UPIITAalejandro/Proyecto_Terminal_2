# %%
import pandas as pd
import numpy as np

pd.options.display.max_columns = None
pd.options.display.max_rows = None

# %%
df_2000 = pd.read_csv("2000.csv")
df_2001 = pd.read_csv("2001.csv")
df_2002 = pd.read_csv("2002.csv")
df_2003 = pd.read_csv("2003.csv")
df_2004 = pd.read_csv("2004.csv")
df_2005 = pd.read_csv("2005.csv")
df_2006 = pd.read_csv("2006.csv")
df_2007 = pd.read_csv("2007.csv")
df_2008 = pd.read_csv("2008.csv")
df_2009 = pd.read_csv("2009.csv")
df_2010 = pd.read_csv("2010.csv")
df_2011 = pd.read_csv("2011.csv")
df_2012 = pd.read_csv("2012.csv")
df_2013 = pd.read_csv("2013.csv")
df_2014 = pd.read_csv("2014.csv")
df_2015 = pd.read_csv("2015.csv")
df_2016 = pd.read_csv("2016.csv")
df_2017 = pd.read_csv("2017.csv")
df_2018 = pd.read_csv("2018.csv")
df_2019 = pd.read_csv("2019.csv")

# %%
df_2000
# Out:
#    Deteccióndepadecimientos_Diabetes  anio   Total
# 0                     Aguascalientes  2000   67543
# 1                    Baja California  2000  122240
# 2                Baja California Sur  2000   29843
# 3                           Campeche  2000   41807
# 4                            Chiapas  2000   82796
# 5                          Chihuahua  2000  199771
# 6                          Coahuila   2000  179643
# 7                             Colima  2000   42920
# 8                         D.F. Norte  2000  354907
# 9                           D.F. Sur  2000  365979
# 10                           Durango  2000   98464
# 11                        Guanajuato  2000  228811
# 12                          Guerrero  2000   79404
# 13                           Hidalgo  2000   57664
# 14                           Jalisco  2000  363714
# 15                    México Oriente  2000  377767
# 16                   México Poniente  2000  214933
# ...

# %%
df_2000.Total
# Out:
# 0      67543
# 1     122240
# 2      29843
# 3      41807
# 4      82796
# 5     199771
# 6     179643
# 7      42920
# 8     354907
# 9     365979
# 10     98464
# 11    228811
# 12     79404
# 13     57664
# 14    363714
# 15    377767
# 16    214933
# 17    131023
# 18     90151
# 19     44770
# 20    414512
# 21     70951
# 22    194299
# 23     64929
# 24     52489
# 25     60937
# 26    219987
# 27    136037
# 28     50235
# 29    221992
# 30     41538
# 31    163354
# 32    158304
# 33    115214
# 34     46175
# Name: Total, dtype: int64

# %%
df_auxiliar = pd.concat([df_2000.Total,df_2001.Total,df_2002.Total,df_2003.Total,df_2004.Total,df_2005.Total,
                        df_2006.Total,df_2007.Total,df_2008.Total,df_2009.Total,df_2010.Total,df_2011.Total,
                        df_2012.Total,df_2013.Total,df_2014.Total,df_2015.Total,df_2016.Total,df_2017.Total,
                        df_2018.Total,df_2019.Total],axis=1)
df_auxiliar
# Out:
#      Total   Total   Total   Total   Total   Total   Total   Total   Total  \
# 0    67543   76375   77405   74338   74935   21357   29483   78604  133158
# 1   122240  123325  113658  178379  158505   42437   73488  206365  253983
# 2    29843   34749   34263   38348   89279   13408   21050   43319   65500
# 3    41807   41366   46574   53694   63447   13777   24160   29228   20968
# 4    82796   75049   76566   75491   58580   14784   35600  111003  133367
# 5   199771  208851  251252  244106  338580   93994  119561  219450  255615
# 6   179643  224937  219128  266316  363994   92649  119856  235882  284550
# 7    42920   46691   39286   38906   44102   13492   21803   39648   50894
# 8   354907  315949  338199  363258  466068  152312  165610  306585  538893
# 9   365979  418975  432112  453825  309819  111194  155963  300465  381977
# 10   98464  105907  105794  134825  118771   30547   41499  103150  115408
# ...

# %% [markdown]
# Orservabdo las caracteristicas de los datos del IMSS se debe de proceder a juntar los elementos.

# %%
df_2008.iloc[[8,9],2]
# Out:
# 8    538893
# 9    381977
# Name: Total, dtype: int64

# %%
df_2008.iloc[[8,9],2].sum()
# Out:
# 920870

# %%
df_2008.iloc[[15,16],2]
# Out:
# 15    512808
# 16    215377
# Name: Total, dtype: int64

# %%
df_2008.iloc[[15,16],2].sum()
# Out:
# 728185

# %%
df_2008.iloc[[31,32],2]
# Out:
# 31    286060
# 32    130405
# Name: Total, dtype: int64

# %%
df_2008.iloc[[31,32],2].sum()
# Out:
# 416465

# %%
estados_republica = ['Aguascalientes','Baja California','Baja California Sur','Campeche','Chiapas','Chihuahua','Ciudad De Mexico',
 'Coahuila','Colima','Durango','Guanajuato','Guerrero','Hidalgo','Jalisco','Mexico','Michoacan','Morelos','Nayarit',
 'Nuevo Leon','Oaxaca','Puebla','Queretaro','Quintana Roo','San Luis Potosi','Sinaloa','Sonora','Tabasco','Tamaulipas',
 'Tlaxcala','Veracruz','Yucatan','Zacatecas']

# %%
diccionario_general = {
    'Id':list(range(1,33)),
    'Estados':estados_republica,
    'Total_Casos_Diabetes_2000':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2001':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2002':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2003':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2004':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2005':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2006':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2007':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2008':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2009':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2010':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2011':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2012':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2013':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2014':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2015':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2016':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2017':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2018':list(np.nan for i in range(0,32)),
    'Total_Casos_Diabetes_2019':list(np.nan for i in range(0,32)),
}

# %%
df_general = pd.DataFrame(diccionario_general)

# %%
df_general.head()
# Out:
#    Id              Estados  Total_Casos_Diabetes_2000  \
# 0   1       Aguascalientes                        1.0
# 1   2      Baja California                        NaN
# 2   3  Baja California Sur                        NaN
# 3   4             Campeche                        NaN
# 4   5              Chiapas                        NaN
#
#    Total_Casos_Diabetes_2001  Total_Casos_Diabetes_2002  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#    Total_Casos_Diabetes_2003  Total_Casos_Diabetes_2004  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# ...

# %%
df_general.shape
# Out:
# (32, 22)

# %%
df_auxiliar.iloc[0,0]
# Out:
# 67543

# %%
for i in range(2,len(df_general.columns)):
    df_general.iloc[0,i] = df_auxiliar.iloc[0,i-2]                #Aguascalientes
    df_general.iloc[1,i] = df_auxiliar.iloc[1,i-2]                #Baja California
    df_general.iloc[2,i] = df_auxiliar.iloc[2,i-2]                #Baja California Sur
    df_general.iloc[3,i] = df_auxiliar.iloc[3,i-2]                #Campeche
    df_general.iloc[4,i] = df_auxiliar.iloc[4,i-2]                #Chiapas   
    df_general.iloc[5,i] = df_auxiliar.iloc[5,i-2]                #Chihuahua
    df_general.iloc[6,i] = df_auxiliar.iloc[[8,9],i-2].sum()      #Ciudad de Mexico
    df_general.iloc[7,i] = df_auxiliar.iloc[6,i-2]                #Coahuila
    df_general.iloc[8,i] = df_auxiliar.iloc[7,i-2]                #Colima 
    df_general.iloc[9,i] = df_auxiliar.iloc[10,i-2]               #Durango
    df_general.iloc[10,i] = df_auxiliar.iloc[11,i-2]              #Guanajuato
    df_general.iloc[11,i] = df_auxiliar.iloc[12,i-2]              #Guerrero
    df_general.iloc[12,i] = df_auxiliar.iloc[13,i-2]              #Hidalgo
    df_general.iloc[13,i] = df_auxiliar.iloc[14,i-2]              #Jalisco
    df_general.iloc[14,i] = df_auxiliar.iloc[[15,16],i-2].sum()   #Mexico
    df_general.iloc[15,i] = df_auxiliar.iloc[17,i-2]              #Michoacan
    df_general.iloc[16,i] = df_auxiliar.iloc[18,i-2]              #Morelos
    df_general.iloc[17,i] = df_auxiliar.iloc[19,i-2]              #Nayarit
    df_general.iloc[18,i] = df_auxiliar.iloc[20,i-2]              #Nuevo Leon
    df_general.iloc[19,i] = df_auxiliar.iloc[21,i-2]              #Oaxaca
    df_general.iloc[20,i] = df_auxiliar.iloc[22,i-2]              #Puebla
    df_general.iloc[21,i] = df_auxiliar.iloc[23,i-2]              #Queretaro
    df_general.iloc[22,i] = df_auxiliar.iloc[24,i-2]              #Quitana Roo
    df_general.iloc[23,i] = df_auxiliar.iloc[25,i-2]              #San Luis Potosi
    df_general.iloc[24,i] = df_auxiliar.iloc[26,i-2]              #Sinaloa
    df_general.iloc[25,i] = df_auxiliar.iloc[27,i-2]              #Sonora
    df_general.iloc[26,i] = df_auxiliar.iloc[28,i-2]              #Tabasco 
    df_general.iloc[27,i] = df_auxiliar.iloc[29,i-2]              #Tamaulipas
    df_general.iloc[28,i] = df_auxiliar.iloc[30,i-2]              #Tlaxcala
    df_general.iloc[29,i] = df_auxiliar.iloc[[31,32],i-2].sum()   #Veracruz
    df_general.iloc[30,i] = df_auxiliar.iloc[33,i-2]              #Yucatan
    df_general.iloc[31,i] = df_auxiliar.iloc[34,i-2]              #Zacatecas

# %%
len(df_general.columns)
# Out:
# 22

# %%
df_2000
# Out:
#    Deteccióndepadecimientos_Diabetes  anio   Total
# 0                     Aguascalientes  2000   67543
# 1                    Baja California  2000  122240
# 2                Baja California Sur  2000   29843
# 3                           Campeche  2000   41807
# 4                            Chiapas  2000   82796
# 5                          Chihuahua  2000  199771
# 6                          Coahuila   2000  179643
# 7                             Colima  2000   42920
# 8                         D.F. Norte  2000  354907
# 9                           D.F. Sur  2000  365979
# 10                           Durango  2000   98464
# 11                        Guanajuato  2000  228811
# 12                          Guerrero  2000   79404
# 13                           Hidalgo  2000   57664
# 14                           Jalisco  2000  363714
# 15                    México Oriente  2000  377767
# 16                   México Poniente  2000  214933
# ...

# %%
df_general
# Out:
#     Id              Estados  Total_Casos_Diabetes_2000  \
# 0    1       Aguascalientes                    67543.0
# 1    2      Baja California                   122240.0
# 2    3  Baja California Sur                    29843.0
# 3    4             Campeche                    41807.0
# 4    5              Chiapas                    82796.0
# 5    6            Chihuahua                   199771.0
# 6    7     Ciudad De Mexico                   720886.0
# 7    8             Coahuila                   179643.0
# 8    9               Colima                    42920.0
# 9   10              Durango                    98464.0
# 10  11           Guanajuato                   228811.0
# 11  12             Guerrero                    79404.0
# 12  13              Hidalgo                    57664.0
# 13  14              Jalisco                   363714.0
# 14  15               Mexico                   592700.0
# 15  16            Michoacan                   131023.0
# ...

# %%
df_general.to_csv("Casos_Diabetes_IMSS.csv", index=False)

# %%
df_general.head()
# Out:
#    Id              Estados  Total_Casos_Diabetes_2000  \
# 0   1       Aguascalientes                    67543.0
# 1   2      Baja California                   122240.0
# 2   3  Baja California Sur                    29843.0
# 3   4             Campeche                    41807.0
# 4   5              Chiapas                    82796.0
#
#    Total_Casos_Diabetes_2001  Total_Casos_Diabetes_2002  \
# 0                    76375.0                    77405.0
# 1                   123325.0                   113658.0
# 2                    34749.0                    34263.0
# 3                    41366.0                    46574.0
# 4                    75049.0                    76566.0
#
#    Total_Casos_Diabetes_2003  Total_Casos_Diabetes_2004  \
# 0                    74338.0                    74935.0
# 1                   178379.0                   158505.0
# 2                    38348.0                    89279.0
# 3                    53694.0                    63447.0
# ...
